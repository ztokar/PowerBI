# %% [markdown]
# <a href="https://colab.research.google.com/github/ztokar/PowerBI/blob/main/TIitanicPrac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/sample_data/titanic.csv")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
#pd.options.display.max_rows= NUMBER to change display settings
df.head(8)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe(include='O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# ##Pandas Data Exploration
# # Dr.Wegman
# #### 2023
# *Italics*
# **Bold**
# >Blocked quote this is what he said

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 891

# %%
round(df,0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0        S  NaN
# 887         1       1  female  19.0      0      0  30.0        S    B
# 888         0       3  female   NaN      1      2  23.0        S  NaN
# 889         1       1    male  26.0      0      0  30.0        C    C
# 890         0       3    male  32.0      0      0   8.0        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.index  #shape also size
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.min()
# Out:
# <ipython-input-11-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare           0.0
# dtype: object

# %%
df.mean().sort_values().head()
# Out:
# <ipython-input-12-5ad2170475f9>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean().sort_values().head()
# parch        0.381594
# survived     0.383838
# sibsp        0.523008
# pclass       2.308642
# age         29.699118
# dtype: float64

# %%
olympic=pd.read_csv("/content/sample_data/summer.csv",index_col='Athlete')
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
olympic.iloc[2:-3000]
# Out:
#                        Year     City     Sport Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios      1896   Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896   Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896   Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896   Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896   Athens  Aquatics   Swimming     HUN    Men
# ...                     ...      ...       ...        ...     ...    ...
# VEZZALI, Valentina     2008  Beijing   Fencing    Fencing     ITA  Women
# BOYKO, Svetlana        2008  Beijing   Fencing    Fencing     RUS  Women
# CHANAEVA, Aida         2008  Beijing   Fencing    Fencing     RUS  Women
# LAMONOVA, Evgenia      2008  Beijing   Fencing    Fencing     RUS  Women
# NIKICHINA, Victoria    2008  Beijing   Fencing    Fencing     RUS  Women
#
#                                             Event   Medal
# Athlete
# ...

# %%
olympic.Country.equals(olympic.iloc[:,2])  #olympic["Country"]
# Out:
# False

# %%
olympic.loc["PHELPS, Michael","Medal"]
# Out:
# Athlete
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# Name: Medal, dtype: object

# %%
olympic.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
#olympic.loc["HERSCHMANN, Otto":'DRIVAS, Dimitrios',"Country":"Event"]
olympic.City
# Out:
# Athlete
# HAJOS, Alfred                Athens
# HERSCHMANN, Otto             Athens
# DRIVAS, Dimitrios            Athens
# MALOKINIS, Ioannis           Athens
# CHASAPIS, Spiridon           Athens
#                               ...
# JANIKOWSKI, Damian           London
# REZAEI, Ghasem Gholamreza    London
# TOTROV, Rustam               London
# ALEKSANYAN, Artur            London
# LIDBERG, Jimmy               London
# Name: City, Length: 31165, dtype: object

# %%
df.head()
age=df.age
type(age)
frm=age.to_frame()
frm
age.equals(frm)
# Out:
# False

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
age.size
age.count()
# Out:
# 714

# %%
age.unique()
age.value_counts(normalize=True,sort=True, ascending=False,dropna=False)
# Out:
# NaN      0.198653
# 24.00    0.033670
# 22.00    0.030303
# 18.00    0.029181
# 28.00    0.028058
#            ...
# 36.50    0.001122
# 55.50    0.001122
# 0.92     0.001122
# 23.50    0.001122
# 74.00    0.001122
# Name: age, Length: 89, dtype: float64

# %%
age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
age.sort_values(ascending=False,na_position='last',inplace=False)
# Out:
# 630    80.0
# 851    74.0
# 493    71.0
# 96     71.0
# 116    70.5
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: age, Length: 891, dtype: float64

# %%
df.head()
mask1=df.sex=="male"
mask2=df.dtypes==object
df.loc[mask1,mask2]
mask2
# Out:
# survived    False
# pclass      False
# sex          True
# age         False
# sibsp       False
# parch       False
# fare        False
# embarked     True
# deck         True
# dtype: bool

# %%
mask3=df.sex=='male'
mask4=df.age>14
(mask3 & mask4).head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
df.loc[mask3 & mask4,::2]
# Out:
#      survived   sex  sibsp     fare deck
# 0           0  male      1   7.2500  NaN
# 4           0  male      0   8.0500  NaN
# 6           0  male      0  51.8625    E
# 12          0  male      0   8.0500  NaN
# 13          0  male      1  31.2750  NaN
# ..        ...   ...    ...      ...  ...
# 883         0  male      0  10.5000  NaN
# 884         0  male      0   7.0500  NaN
# 886         0  male      0  13.0000  NaN
# 889         1  male      0  30.0000    C
# 890         0  male      0   7.7500  NaN
#
# [414 rows x 5 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
df.fare=df.fare*10
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   72.500        S  NaN
# 1         1       1  female  38.0      1      0  712.833        C    C
# 2         1       3  female  26.0      0      0   79.250        S  NaN
# 3         1       1  female  35.0      1      0  531.000        S    C
# 4         0       3    male  35.0      0      0   80.500        S  NaN

# %%
df["relatives"]=df.sibsp+df.parch
df.drop(columns=["sibsp",'parch'],inplace=True)
df.head()
# Out:
#    survived  pclass     sex   age     fare embarked deck  relatives
# 0         0       3    male  22.0   72.500        S  NaN          1
# 1         1       1  female  38.0  712.833        C    C          1
# 2         1       3  female  26.0   79.250        S  NaN          0
# 3         1       1  female  35.0  531.000        S    C          1
# 4         0       3    male  35.0   80.500        S  NaN          0
